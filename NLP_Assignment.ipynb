# %% [markdown]
# # NLP Assignment: Feature Engineering, Similarity, Classification & Clustering

# %% [markdown]
# ## Feature Engineering using TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

corpus = [
    "I love machine learning",
    "Data science is amazing",
    "I enjoy learning new technologies"
]

vectorizer = TfidfVectorizer()
X_tfidf = vectorizer.fit_transform(corpus)

print(X_tfidf.toarray())
print(vectorizer.get_feature_names_out())
# Out:
# [[0.         0.         0.         0.         0.4736296  0.62276601
#   0.62276601 0.         0.         0.        ]
#  [0.5        0.5        0.         0.5        0.         0.
#   0.         0.         0.5        0.        ]
#  [0.         0.         0.52863461 0.         0.40204024 0.
#   0.         0.52863461 0.         0.52863461]]
# ['amazing' 'data' 'enjoy' 'is' 'learning' 'love' 'machine' 'new' 'science'
#  'technologies']

# %% [markdown]
# ## Cosine Similarity between Sentences

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer

sentences = [
    "I love machine learning",
    "Machine learning is great",
    "I enjoy pizza"
]

tfidf = TfidfVectorizer().fit_transform(sentences)
cos_sim = cosine_similarity(tfidf)

print(cos_sim)
# Out:
# [[1.         0.44333251 0.        ]
#  [0.44333251 1.         0.        ]
#  [0.         0.         1.        ]]

# %% [markdown]
# ## Text Classification (Logistic Regression)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer

texts = [
    "I love this product",
    "This is terrible",
    "Amazing experience",
    "Worst service ever"
]

labels = [1, 0, 1, 0]

X = TfidfVectorizer().fit_transform(texts)

X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size=0.2)

model = LogisticRegression()
model.fit(X_train, y_train)

print("Accuracy:", model.score(X_test, y_test))
# Out:
# Accuracy: 0.0

# %% [markdown]
# ## Text Clustering (K-Means)

# %%
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer

texts1 = [
    "I love AI",
    "Machine learning is cool",
    "Pizza is tasty",
    "I like food"
]

x1 = TfidfVectorizer().fit_transform(texts)

kmeans = KMeans(n_clusters=2, random_state=0)
kmeans.fit(x1)

print(kmeans.labels_)
# Out:
# c:\Users\304ch\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [0 0 0 1]
